# %%
from src.release import from_distribution
from src.util import noisy_max
from src.util import noisy_min
from src.visual import plot_posterior

from sympy.stats import Normal

a = from_distribution(-1, Normal, 0, 2)
b = from_distribution(1, Normal, 0, 2)

plot_posterior(a, b, noisy_max(a, b), noisy_min(a, b))
# Out:
# {'ax': <Axes: title={'center': 'Posterior Densities of Composed Expressions'}, xlabel='Expression value', ylabel='Posterior density'>,
#  'curves': [{'noisy_value': NoisyFloat(expr=theta_10, observed=3.010817230840215),
#    'x': array([-2.70095054e+00, -2.67805769e+00, -2.65516483e+00, -2.63227197e+00,
#           -2.60937912e+00, -2.58648626e+00, -2.56359340e+00, -2.54070055e+00,
#           -2.51780769e+00, -2.49491483e+00, -2.47202198e+00, -2.44912912e+00,
#           -2.42623626e+00, -2.40334341e+00, -2.38045055e+00, -2.35755769e+00,
#           -2.33466484e+00, -2.31177198e+00, -2.28887912e+00, -2.26598626e+00,
#           -2.24309341e+00, -2.22020055e+00, -2.19730769e+00, -2.17441484e+00,
#           -2.15152198e+00, -2.12862912e+00, -2.10573627e+00, -2.08284341e+00,
#           -2.05995055e+00, -2.03705770e+00, -2.01416484e+00, -1.99127198e+00,
#           -1.96837913e+00, -1.94548627e+00, -1.92259341e+00, -1.89970056e+00,
# ...
